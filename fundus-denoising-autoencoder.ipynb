# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/good-img/4_good.JPG
# /kaggle/input/good-img/16_good.JPG
# /kaggle/input/good-img/10_good.JPG
# /kaggle/input/good-img/1_good.JPG
# /kaggle/input/good-img/8_good.JPG
# /kaggle/input/good-img/11_good.JPG
# /kaggle/input/good-img/3_good.JPG
# /kaggle/input/good-img/15_good.JPG
# /kaggle/input/good-img/7_good.JPG
# /kaggle/input/good-img/2_good.JPG
# /kaggle/input/good-img/13_good.JPG
# /kaggle/input/good-img/18_good.JPG
# /kaggle/input/good-img/5_good.JPG
# /kaggle/input/good-img/6_good.JPG
# /kaggle/input/good-img/17_good.JPG
# /kaggle/input/good-img/12_good.JPG
# /kaggle/input/good-img/14_good.JPG
# /kaggle/input/good-img/9_good.JPG
# /kaggle/input/bad-img/9_bad.JPG
# /kaggle/input/bad-img/8_bad.JPG
# /kaggle/input/bad-img/18_bad.JPG
# /kaggle/input/bad-img/12_bad.JPG
# /kaggle/input/bad-img/11_bad.JPG
# /kaggle/input/bad-img/3_bad.JPG
# /kaggle/input/bad-img/4_bad.JPG
# /kaggle/input/bad-img/7_bad.JPG
# /kaggle/input/bad-img/15_bad.JPG
# /kaggle/input/bad-img/1_bad.JPG
# /kaggle/input/bad-img/5_bad.JPG
# /kaggle/input/bad-img/17_bad.JPG
# /kaggle/input/bad-img/14_bad.JPG
# /kaggle/input/bad-img/10_bad.JPG
# /kaggle/input/bad-img/13_bad.JPG
# /kaggle/input/bad-img/16_bad.JPG
# /kaggle/input/bad-img/6_bad.JPG
# /kaggle/input/bad-img/2_bad.JPG

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Sequential

import numpy as np
import matplotlib.pyplot as plt

import os
import cv2
from keras.preprocessing.image import img_to_array

# x is noisy data and y is clean data
SIZE = 2048

from tqdm import tqdm
folder = '../input/bad-img'
files=os.listdir(folder)
print(files)
sortedfiles=sorted(files)
print(sortedfiles)
noisy_data=[]
for filename in sortedfiles:
    img = cv2.imread(os.path.join(folder, filename), cv2.IMREAD_COLOR)
    img=cv2.resize(img,(SIZE, SIZE))
    noisy_data.append(img_to_array(img))

folder1 = '../input/good-img'
files1=os.listdir(folder1)
print(files1)
sortedfiles1=sorted(files1)
print(sortedfiles1)
clean_data=[]
for filename in sortedfiles1:
    img = cv2.imread(os.path.join(folder1, filename), cv2.IMREAD_COLOR)
    img=cv2.resize(img,(SIZE, SIZE))
    clean_data.append(img_to_array(img))

noisy_train = np.reshape(noisy_data, (len(noisy_data), SIZE, SIZE, 3))
noisy_train = noisy_train.astype('float32') / 255.

clean_train = np.reshape(clean_data, (len(clean_data), SIZE, SIZE, 3))
clean_train = clean_train.astype('float32') / 255.


#Displaying images with noise
plt.figure(figsize=(10, 2))
for i in range(1,4):
    ax = plt.subplot(1, 4, i)
    plt.imshow(cv2.cvtColor(noisy_train[i].reshape(SIZE, SIZE,3), cv2.COLOR_BGR2RGB))
plt.show()

#Displaying clean images
plt.figure(figsize=(10, 2))
for i in range(1,4):
    ax = plt.subplot(1, 4, i)
    plt.imshow(cv2.cvtColor(clean_train[i].reshape(SIZE, SIZE,3), cv2.COLOR_BGR2RGB))
plt.show()



model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(SIZE, SIZE, 3)))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
 

model.add(MaxPooling2D((2, 2), padding='same'))
     
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(3, (3, 3), activation='relu', padding='same'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

model.summary()

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(noisy_train, clean_train, 
                                                    test_size = 0.05, random_state = 0)


model.fit(x_train, y_train, epochs=60, batch_size=1, shuffle=True, verbose =1,
          validation_split = 0.3)


print("Test_Accuracy: {:.2f}%".format(model.evaluate(np.array(x_test), np.array(y_test))[1]*100))


#model.save('denoising_autoencoder.model')

no_noise_img = model.predict(x_test)

#Displaying images with noise
plt.figure(figsize=(10, 2))
for i in range(1,2):
    ax = plt.subplot(1, 4, i)
    img0=cv2.cvtColor(x_test[i-1].reshape(SIZE, SIZE,3), cv2.COLOR_BGR2RGB)
    #plt.imsave('./noised_image.jpg', img0)
    plt.imshow(cv2.cvtColor(x_test[i-1].reshape(SIZE, SIZE,3), cv2.COLOR_BGR2RGB))
plt.show()

#Displaying clean images
plt.figure(figsize=(10, 2))
for i in range(1,2):
    ax = plt.subplot(1, 4, i)
    img1=cv2.cvtColor(no_noise_img[i-1].reshape(SIZE, SIZE,3), cv2.COLOR_BGR2RGB)
    plt.imsave('./denoised_image.jpg', img1)
    #plt.imshow(cv2.cvtColor(no_noise_img[i-1].reshape(SIZE, SIZE,3), cv2.COLOR_BGR2RGB))
    plt.imshow(cv2.cvtColor(no_noise_img[i-1].reshape(SIZE, SIZE,3), cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ['9_bad.JPG', '8_bad.JPG', '18_bad.JPG', '12_bad.JPG', '11_bad.JPG', '3_bad.JPG', '4_bad.JPG', '7_bad.JPG', '15_bad.JPG', '1_bad.JPG', '5_bad.JPG', '17_bad.JPG', '14_bad.JPG', '10_bad.JPG', '13_bad.JPG', '16_bad.JPG', '6_bad.JPG', '2_bad.JPG']
# ['10_bad.JPG', '11_bad.JPG', '12_bad.JPG', '13_bad.JPG', '14_bad.JPG', '15_bad.JPG', '16_bad.JPG', '17_bad.JPG', '18_bad.JPG', '1_bad.JPG', '2_bad.JPG', '3_bad.JPG', '4_bad.JPG', '5_bad.JPG', '6_bad.JPG', '7_bad.JPG', '8_bad.JPG', '9_bad.JPG']
# ['4_good.JPG', '16_good.JPG', '10_good.JPG', '1_good.JPG', '8_good.JPG', '11_good.JPG', '3_good.JPG', '15_good.JPG', '7_good.JPG', '2_good.JPG', '13_good.JPG', '18_good.JPG', '5_good.JPG', '6_good.JPG', '17_good.JPG', '12_good.JPG', '14_good.JPG', '9_good.JPG']
# ['10_good.JPG', '11_good.JPG', '12_good.JPG', '13_good.JPG', '14_good.JPG', '15_good.JPG', '16_good.JPG', '17_good.JPG', '18_good.JPG', '1_good.JPG', '2_good.JPG', '3_good.JPG', '4_good.JPG', '5_good.JPG', '6_good.JPG', '7_good.JPG', '8_good.JPG', '9_good.JPG']
# 2021-12-05 12:44:10.594529: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-05 12:44:10.728049: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-05 12:44:10.729169: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-05 12:44:10.730941: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-05 12:44:10.732215: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-05 12:44:10.733215: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-05 12:44:10.734190: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-05 12:44:13.038551: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-05 12:44:13.039604: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-05 12:44:13.040767: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-05 12:44:13.041717: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 2048, 2048, 32)    896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 1024, 1024, 32)    0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 1024, 1024, 8)     2312
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 512, 512, 8)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 512, 512, 8)       584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 256, 256, 8)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 256, 256, 8)       584
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 512, 512, 8)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 512, 512, 8)       584
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 1024, 1024, 8)     0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 1024, 1024, 32)    2336
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 2048, 2048, 32)    0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 2048, 2048, 3)     867
# =================================================================
# Total params: 8,163
# Trainable params: 8,163
# Non-trainable params: 0
# _________________________________________________________________
# 2021-12-05 12:44:15.102627: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 553648128 exceeds 10% of free system memory.
# 2021-12-05 12:44:15.633336: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 553648128 exceeds 10% of free system memory.
# 2021-12-05 12:44:16.206012: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 553648128 exceeds 10% of free system memory.
# 2021-12-05 12:44:16.629108: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 553648128 exceeds 10% of free system memory.
# 2021-12-05 12:44:17.088658: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/60
# 2021-12-05 12:44:19.077943: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 11/11 [==============================] - 12s 297ms/step - loss: 0.0136 - accuracy: 0.4313 - val_loss: 0.0100 - val_accuracy: 0.4752
# Epoch 2/60
# 11/11 [==============================] - 2s 179ms/step - loss: 0.0035 - accuracy: 0.4823 - val_loss: 0.0077 - val_accuracy: 0.4752
# Epoch 3/60
# 11/11 [==============================] - 2s 191ms/step - loss: 0.0023 - accuracy: 0.4823 - val_loss: 0.0081 - val_accuracy: 0.4753
# Epoch 4/60
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0021 - accuracy: 0.7357 - val_loss: 0.0069 - val_accuracy: 0.8620
# Epoch 5/60
# 11/11 [==============================] - 3s 276ms/step - loss: 0.0021 - accuracy: 0.8554 - val_loss: 0.0068 - val_accuracy: 0.8642
# Epoch 6/60
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0020 - accuracy: 0.8563 - val_loss: 0.0073 - val_accuracy: 0.8630
# Epoch 7/60
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0021 - accuracy: 0.8560 - val_loss: 0.0071 - val_accuracy: 0.8636
# Epoch 8/60
# 11/11 [==============================] - 2s 188ms/step - loss: 0.0020 - accuracy: 0.8575 - val_loss: 0.0074 - val_accuracy: 0.8655
# Epoch 9/60
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0019 - accuracy: 0.8574 - val_loss: 0.0070 - val_accuracy: 0.8670
# Epoch 10/60
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0020 - accuracy: 0.8569 - val_loss: 0.0068 - val_accuracy: 0.8583
# Epoch 11/60
# 11/11 [==============================] - 2s 193ms/step - loss: 0.0020 - accuracy: 0.8532 - val_loss: 0.0072 - val_accuracy: 0.8621
# Epoch 12/60
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0019 - accuracy: 0.8551 - val_loss: 0.0068 - val_accuracy: 0.8661
# Epoch 13/60
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0019 - accuracy: 0.8583 - val_loss: 0.0067 - val_accuracy: 0.8675
# Epoch 14/60
# 11/11 [==============================] - 2s 195ms/step - loss: 0.0019 - accuracy: 0.8603 - val_loss: 0.0069 - val_accuracy: 0.8683
# Epoch 15/60
# 11/11 [==============================] - 2s 192ms/step - loss: 0.0017 - accuracy: 0.8613 - val_loss: 0.0075 - val_accuracy: 0.8689
# Epoch 16/60
# 11/11 [==============================] - 2s 187ms/step - loss: 0.0018 - accuracy: 0.8614 - val_loss: 0.0071 - val_accuracy: 0.8695
# Epoch 17/60
# 11/11 [==============================] - 2s 177ms/step - loss: 0.0018 - accuracy: 0.8621 - val_loss: 0.0067 - val_accuracy: 0.8705
# Epoch 18/60
# 11/11 [==============================] - 2s 178ms/step - loss: 0.0015 - accuracy: 0.8627 - val_loss: 0.0035 - val_accuracy: 0.8716
# Epoch 19/60
# 11/11 [==============================] - 2s 205ms/step - loss: 9.3950e-04 - accuracy: 0.8554 - val_loss: 0.0045 - val_accuracy: 0.8710
# Epoch 20/60
# 11/11 [==============================] - 2s 204ms/step - loss: 9.8895e-04 - accuracy: 0.8639 - val_loss: 0.0044 - val_accuracy: 0.8717
# Epoch 21/60
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0013 - accuracy: 0.8637 - val_loss: 0.0034 - val_accuracy: 0.8717
# Epoch 22/60
# 11/11 [==============================] - 2s 185ms/step - loss: 8.6902e-04 - accuracy: 0.8641 - val_loss: 0.0033 - val_accuracy: 0.8727
# Epoch 23/60
# 11/11 [==============================] - 2s 179ms/step - loss: 0.0013 - accuracy: 0.8643 - val_loss: 0.0033 - val_accuracy: 0.8718
# Epoch 24/60
# 11/11 [==============================] - 2s 182ms/step - loss: 7.9215e-04 - accuracy: 0.8639 - val_loss: 0.0029 - val_accuracy: 0.8726
# Epoch 25/60
# 11/11 [==============================] - 2s 202ms/step - loss: 7.8334e-04 - accuracy: 0.8644 - val_loss: 0.0028 - val_accuracy: 0.8728
# Epoch 26/60
# 11/11 [==============================] - 2s 189ms/step - loss: 8.2909e-04 - accuracy: 0.8646 - val_loss: 0.0038 - val_accuracy: 0.8727
# Epoch 27/60
# 11/11 [==============================] - 2s 192ms/step - loss: 8.0679e-04 - accuracy: 0.8646 - val_loss: 0.0042 - val_accuracy: 0.8723
# Epoch 28/60
# 11/11 [==============================] - 2s 191ms/step - loss: 7.3041e-04 - accuracy: 0.8643 - val_loss: 0.0035 - val_accuracy: 0.8728
# Epoch 29/60
# 11/11 [==============================] - 2s 186ms/step - loss: 7.7782e-04 - accuracy: 0.8646 - val_loss: 0.0044 - val_accuracy: 0.8728
# Epoch 30/60
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0010 - accuracy: 0.8646 - val_loss: 0.0032 - val_accuracy: 0.8728
# Epoch 31/60
# 11/11 [==============================] - 2s 186ms/step - loss: 9.4002e-04 - accuracy: 0.8645 - val_loss: 0.0031 - val_accuracy: 0.8731
# Epoch 32/60
# 11/11 [==============================] - 2s 192ms/step - loss: 9.3434e-04 - accuracy: 0.8647 - val_loss: 0.0031 - val_accuracy: 0.8731
# Epoch 33/60
# 11/11 [==============================] - 2s 193ms/step - loss: 8.8830e-04 - accuracy: 0.8647 - val_loss: 0.0030 - val_accuracy: 0.8732
# Epoch 34/60
# 11/11 [==============================] - 2s 189ms/step - loss: 7.5322e-04 - accuracy: 0.8647 - val_loss: 0.0029 - val_accuracy: 0.8732
# Epoch 35/60
# 11/11 [==============================] - 3s 269ms/step - loss: 8.7131e-04 - accuracy: 0.8647 - val_loss: 0.0036 - val_accuracy: 0.8731
# Epoch 36/60
# 11/11 [==============================] - 2s 224ms/step - loss: 7.7494e-04 - accuracy: 0.8647 - val_loss: 0.0037 - val_accuracy: 0.8729
# Epoch 37/60
# 11/11 [==============================] - 2s 201ms/step - loss: 8.3047e-04 - accuracy: 0.8646 - val_loss: 0.0051 - val_accuracy: 0.8731
# Epoch 38/60
# 11/11 [==============================] - 2s 180ms/step - loss: 8.3330e-04 - accuracy: 0.8649 - val_loss: 0.0047 - val_accuracy: 0.8733
# Epoch 39/60
# 11/11 [==============================] - 2s 197ms/step - loss: 0.0012 - accuracy: 0.8642 - val_loss: 0.0038 - val_accuracy: 0.8732
# Epoch 40/60
# 11/11 [==============================] - 2s 211ms/step - loss: 8.0258e-04 - accuracy: 0.8648 - val_loss: 0.0034 - val_accuracy: 0.8733
# Epoch 41/60
# 11/11 [==============================] - 2s 181ms/step - loss: 6.7424e-04 - accuracy: 0.8649 - val_loss: 0.0036 - val_accuracy: 0.8733
# Epoch 42/60
# 11/11 [==============================] - 2s 185ms/step - loss: 7.4876e-04 - accuracy: 0.8649 - val_loss: 0.0037 - val_accuracy: 0.8733
# Epoch 43/60
# 11/11 [==============================] - 2s 196ms/step - loss: 6.6474e-04 - accuracy: 0.8650 - val_loss: 0.0032 - val_accuracy: 0.8734
# Epoch 44/60
# 11/11 [==============================] - 2s 201ms/step - loss: 7.7945e-04 - accuracy: 0.8649 - val_loss: 0.0030 - val_accuracy: 0.8734
# Epoch 45/60
# 11/11 [==============================] - 2s 196ms/step - loss: 6.8195e-04 - accuracy: 0.8649 - val_loss: 0.0037 - val_accuracy: 0.8734
# Epoch 46/60
# 11/11 [==============================] - 2s 190ms/step - loss: 6.6294e-04 - accuracy: 0.8650 - val_loss: 0.0037 - val_accuracy: 0.8735
# Epoch 47/60
# 11/11 [==============================] - 2s 177ms/step - loss: 7.1451e-04 - accuracy: 0.8649 - val_loss: 0.0035 - val_accuracy: 0.8736
# Epoch 48/60
# 11/11 [==============================] - 2s 192ms/step - loss: 8.0091e-04 - accuracy: 0.8638 - val_loss: 0.0030 - val_accuracy: 0.8735
# Epoch 49/60
# 11/11 [==============================] - 2s 193ms/step - loss: 7.3707e-04 - accuracy: 0.8638 - val_loss: 0.0035 - val_accuracy: 0.8735
# Epoch 50/60
# 11/11 [==============================] - 2s 188ms/step - loss: 7.0652e-04 - accuracy: 0.8650 - val_loss: 0.0036 - val_accuracy: 0.8735
# Epoch 51/60
# 11/11 [==============================] - 2s 204ms/step - loss: 7.9588e-04 - accuracy: 0.8650 - val_loss: 0.0036 - val_accuracy: 0.8737
# Epoch 52/60
# 11/11 [==============================] - 2s 221ms/step - loss: 6.8873e-04 - accuracy: 0.8652 - val_loss: 0.0043 - val_accuracy: 0.8737
# Epoch 53/60
# 11/11 [==============================] - 2s 174ms/step - loss: 6.8257e-04 - accuracy: 0.8649 - val_loss: 0.0032 - val_accuracy: 0.8737
# Epoch 54/60
# 11/11 [==============================] - 2s 183ms/step - loss: 6.9252e-04 - accuracy: 0.8649 - val_loss: 0.0028 - val_accuracy: 0.8734
# Epoch 55/60
# 11/11 [==============================] - 2s 198ms/step - loss: 8.9259e-04 - accuracy: 0.8650 - val_loss: 0.0032 - val_accuracy: 0.8738
# Epoch 56/60
# 11/11 [==============================] - 2s 202ms/step - loss: 9.5699e-04 - accuracy: 0.8650 - val_loss: 0.0029 - val_accuracy: 0.8736
# Epoch 57/60
# 11/11 [==============================] - 2s 185ms/step - loss: 8.3167e-04 - accuracy: 0.8650 - val_loss: 0.0035 - val_accuracy: 0.8738
# Epoch 58/60
# 11/11 [==============================] - 2s 197ms/step - loss: 8.2794e-04 - accuracy: 0.8650 - val_loss: 0.0038 - val_accuracy: 0.8736
# Epoch 59/60
# 11/11 [==============================] - 2s 188ms/step - loss: 7.3630e-04 - accuracy: 0.8651 - val_loss: 0.0032 - val_accuracy: 0.8738
# Epoch 60/60
# 11/11 [==============================] - 2s 191ms/step - loss: 6.8609e-04 - accuracy: 0.8652 - val_loss: 0.0038 - val_accuracy: 0.8738
# 1/1 [==============================] - 0s 271ms/step - loss: 0.0016 - accuracy: 0.8374
# Test_Accuracy: 83.74%
